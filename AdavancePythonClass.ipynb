# %%
a = 10
b = 3.14
c = "25"
d = "3.5"
e = True

# %%
# int
print(int(b))
print(int(c))
print(int(e))

# %%
# float
print(float(a))
print(float(c))
print(float(e))

# %%
# string
print(str(a))
print(str(b))
print(str(e))

# %%
a, b = 10, 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a ** b)
print(a // b)

# %%
a, b = 10, 5
print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)

# %%
a, b = True, False

print(a and b)
print(a or b)
print(not a)

# %%
print("Hello world")

# %% [markdown]
# DATE - 27 / 01 / 2026

# %%
st = "abcd"
print(st)
print(st[0])
#st[0] = "r" Error because string are immutable
print(st[0])

# %%
mul = """aaa
bbb
ccc"""
mul2 = '''aaa
bbb
zzz'''
print(mul2)
print(mul)

# %%
print(mul == mul2)
print(mul is mul2)

# %%
for i in mul:
  print(i)

# %%
len(mul)

# %%
print("a" in mul)
print("A" in mul)

# %%
print(mul.upper())

# %%
print(mul.partition(" "))

# %%
name = "Patrickk"
srt = f"My name is {name}"
print(srt)

# %%
a = "Python"
b = "Java"
c = "C++"
tp = (a,b,c)
print(tp)
x,y,z = tp
print(x)
print(y)
print(z)

# %%
tp2 = sorted(tp)
print(tp2)

# %%
print(name.capitalize())
print(name.title())
print(name.swapcase())
print(name[0])
print(name[-1])
print(name[::-1])

# %%
print("Pascal Case, Camel Case, Snake Case, Kebab Case")

# %% [markdown]
# DATE - 29 / 01 / 2026

# %%
x1 = [1,2,3,4]
x2 = [1,2,3,4]
print(x1 == x2)

# %%
lst2 = [1,5,2,3,4,4,5,1]
st = set(lst2)
print(st)

# %%
lst2.extend((10,12,20))
print(lst2)

# %% [markdown]
# ATM PROGRAM WITH PIN

# %%
balance =  0
transaction = []
pin = 1609
cnt = 0
approve = False
while cnt <3:
  print(f"Available chances :{3-cnt}")
  code = int(input("Enter your pin :"))
  if code==pin:
    approve = True
    break
  else:
    print("Wrong Pin")
    cnt+=1
while(approve):
  print("\n1 for Deposit")
  print("2 for withdraw")
  print("3 for Balance Inquiry")
  print("4 for All Transactions")
  print("5 for Exit\n")

  ch = int(input("Enter Your Choice :"))

  if ch==1:
    amt = int(input("Enter the amount for deposit :"))
    balance+=amt
    transaction.append(f"Deposit of {amt}")
    print(f"Deposit Successfull of {amt}")
  elif ch==2:
    amt = int(input("Enter the amount you want to withdraw :"))
    if amt>balance:
      print("Insuffecient Balance")
    else:
      balance-=amt
      transaction.append(f"Withdraw of {amt}")
      print(f"Withdraw successfull of {amt}")
  elif ch==3:
    print(f"Account balance :{balance}")
  elif ch==4:
    if len(transaction)==0:
      print("No Transactions")
    else:
      for i in transaction:
        print(i)
  elif ch==5:
    print("Exiting...!")
    break
  else:
    print("Invalid Choice !!")
print("Thank you for using")

# %% [markdown]
# DATE - 31 / 01 / 2026

# %%
st1 = {89,}
print(type(st1))

# %%
st3 = {23,12,15,16}
print(st3.pop())
print(st3.pop())
print(st3.pop())
print(st3.pop())
print(st3)
print(type(st3))

# %%
print(type(st3))

# %%
st4 = {True,False,0,1,"Python"}
print(st4)

# %%
st4.add("Pratik")
st4.discard("Python")
print(st4)

# %%
print("Hello"=="He"+"llo")

# %%
tple =(1,2,3,[4,5])
print(tple)
tple[3][0] = 99
print(tple)

# %%
lst1 = [1,2,3]
tple2 = (4,5,6,lst1)
print(tple2)
tple2[3][1] = 100
print(tple2)
print(lst1)
lst1[2] = 1000
print(lst1)
print(tple2)

# %%
print(len("Python\00Java"))
print(len("Python\AnythingJava"))

# %% [markdown]
# HOMEWORK SET

# %%
#Find Common elements between two lists using set.
lst1 = [1,2,3,4,5]
lst2 = [4,5,6,7,8]
emp = set(lst1).intersection(set(lst2))
print(list(emp))

# %%
#Duplicate Word from a sentence
srt = "Hi Hii Hi Hello"
lst1 = srt.split(" ")
st = set(lst1)
print(st)

# %%
#Present in first list and not in 2nd list
lst1 = [1,2,3,4,5]
lst2 = [4,5,6,7,8]
lst3 = set(lst1).difference(set(lst2))
print(lst3)

# %%
#Character in a string are unique
st = "abcde"
st1 = set(st)
if len(st1)==len(st):
  print("All Unique")

# %%
#Distinct element in list
lst3 =[1,2,3,4,5,6]
st = set(lst3)
print("The number od Distinct elements are",len(lst3)-(len(lst3)-len(st)))

# %%
#Common elements from two strings
st1 = "ABCDE"
st2 = "CDEFG"
set1 = set(st1)
set2 = set(st2)
print(set1.intersection(set2))

# %%
#If set is subset of another
set3 = {'A','B','C','D','E','F'}
set4 = {'D','E','F'}
cnt = 0
for i in set4:
  if i in set3:
    cnt+=1
if cnt==len(set4):
  print("Set4 is subset of set3")

# %%
#Repeated elements in list
lst5 = [10,20,30,40,50,50,30]
set5 = set(lst5)
for i in set5:
  lst5.remove(i)
print(lst5)

# %%
#Anagrams
wrd = "Throw"
wrd2 = "Worth"
set6 = set(wrd.lower())
set7 = set(wrd2.lower())
if len(set6)==len(set7):
  print("They are Anagrams")

# %%
#Symmetric difference without builtin method
set6 = {100,200,300,400,500}
set8 = {400,500,600,700,800}
z = []
for i in set8:
  if i in set6:
    z.append(i)
y = []
for i in set6:
  if i not in z:
    y.append(i)
for i in set8:
  if i not in z:
    y.append(i)
print(y)

# %% [markdown]
# EVENT TRACKER SET

# %%
entered_std = set()
rejected_std = set()

n = int(input("Enter Entry attempt: "))

for i in range(n):
  name = input("Enter student names: ").lower()
  name2 = ("").join((name.split(" ")))

  if name2 in entered_std:
    print(name, "already entered. entry rejected")
    rejected_std.add(name2)

  else:
    print(name, "Entry allowed")
    entered_std.add(name2)
print("Event details:")
print("\nTotal unique entry :",len(entered_std))
for j in entered_std:
  print(j)
print("\nTotal rejected entry :",len(rejected_std))
for k in rejected_std:
  print(k)

# %% [markdown]
# ROOM ALLOTMENT USING DICTIONARY

# %%
rooms = {100:None,101:None,102:None,103:None,104:None,105:None,106:None,107:None,108:None,109:None}


print("Available rooms :")
for j in rooms:
  print(j,end=" ")

n = int(input("Enter Entry attempt: "))
for i in range(n):
  rmno = int(input("Enter the room number :"))
  if rooms[rmno] !=None:
    print("Room already alloted !!")
  else:
    name = input("Enter your name :")
    rooms[rmno] = name
    print(f"Room Alloted successfully to {name}")


delrom = int(input("Enter the room to vacate :"))
if rooms[delrom]==None or delrom not in rooms:
  print("Cannot vacate Room or room already vacate")
else:
  rooms[delrom] = None
  print(f"Room checkout Successfully !!")


print("All Booked rooms details :")
for j in rooms:
  if rooms[j]!=None :
    print(f"{j} : {rooms[j]}")

print("All Vacate rooms details :")
for j in rooms:
  if rooms[j]==None :
    print(f"{j} : {rooms[j]}")
print("Thank You !!!")

# %%
def add(a,b):
  print(a+b)
add(2,3)

# %%
def add2(a=3,b=6):
  print(a+b)
add(10,20)

# %% [markdown]
# ATM PROGRAM WITH FUNCTION

# %%
def login(pin, correct_pin=1674):
    return pin == correct_pin


def deposit(balance, transactions):
    amt = int(input("Enter the amount for deposit : "))
    balance += amt
    transactions.append(f"Deposit of {amt}")
    print(f"Deposit Successful of {amt}")
    return balance


def withdraw(balance, transactions):
    amt = int(input("Enter the amount you want to withdraw : "))

    if amt > balance:
        print("Insufficient Balance")
    else:
        balance -= amt
        transactions.append(f"Withdraw of {amt}")
        print(f"Withdraw Successful of {amt}")

    return balance


def history(transactions):
    if not transactions:
        print("No Transactions")
    else:
        for t in transactions:
            print(t)


def view_balance(balance):
    print(f"Account balance : {balance}")

balance = 0
transactions = []
approve = False

for cnt in range(3):
    print(f"Available chances : {3 - cnt}")
    code = int(input("Enter your pin : "))

    if login(code):
        approve = True
        break
    else:
        print("Wrong Pin")

while approve:
    print("\n1 for Deposit")
    print("2 for Withdraw")
    print("3 for Balance Inquiry")
    print("4 for All Transactions")
    print("5 for Exit\n")

    ch = int(input("Enter Your Choice : "))

    if ch == 1:
        balance = deposit(balance, transactions)

    elif ch == 2:
        balance = withdraw(balance, transactions)

    elif ch == 3:
        view_balance(balance)

    elif ch == 4:
        history(transactions)

    elif ch == 5:
        print("Exiting...!")
        break

    else:
        print("Invalid Choice !!")

print("Thank you for using")

# %% [markdown]
# LIBRARY MANAGEMENT

# %%
library = {}
issued_books = {}

book_id = 0
total_books = int(input("Enter the number of books to add: "))

for i in range(total_books):
    title = input("Enter the book title: ")
    writer = input("Enter the author name: ")
    copies = int(input("Enter number of copies: "))

    book_data = {
        "book_id": book_id,
        "Title": title,
        "Author": writer,
        "Stock": copies
    }

    library[book_id] = book_data
    book_id += 1
    print(f"{title} added successfully!!")

print("\nBooks Available:")
for key in library:
    print("ID:", key,
          "Title:", library[key]["Title"],
          "Copies Available:", library[key]["Stock"])

issue_id = 0
issue_count = int(input("\nEnter number of books to issue: "))

for i in range(issue_count):
    selected_id = int(input("Enter Book ID to issue: "))

    if library[selected_id]["Stock"] > 0:
        user_name = input("Enter user name: ")
        user_phone = int(input("Enter user phone number: "))

        issued_books[issue_id] = {
            "Book_ID": selected_id,
            "User_Name": user_name,
            "Book_Title": library[selected_id]["Title"],
            "Phone": user_phone
        }

        print(f"Book ID {selected_id} issued successfully!!")
        library[selected_id]["Stock"] -= 1
        issue_id += 1
    else:
        print("Book not available")

print("\nUpdated Available Books:")
for key in library:
    print("ID:", key,
          "Title:", library[key]["Title"],
          "Copies Available:", library[key]["Stock"])

print("\nAll Issued Records:")
for record in issued_books:
    print("Issue_ID:", record,
          "Book ID:", issued_books[record]["Book_ID"],
          "Issued To:", issued_books[record]["User_Name"])

# %% [markdown]
# TRAFFIC MANAGEMENT

# %%
import time

current_signal = "RED"
print("Signal Color :", current_signal)

while True:
    new_signal = input("Enter the color of the signal (RED,YELLOW,GREEN) or 0 to exit: ")

    if new_signal == "0":
        break

    new_signal = new_signal.upper()

    if new_signal not in ("RED,YELLOW,GREEN") or new_signal == current_signal:
        print("Invalid Signal Color or Cannot be the same as previous color!!")
        continue

    duration = int(input("Enter the time in seconds: "))

    while duration > 0:
        print(f"Time left {duration} second")
        time.sleep(1)
        duration -= 1

    current_signal = new_signal
    print("Color changed to :", current_signal)
